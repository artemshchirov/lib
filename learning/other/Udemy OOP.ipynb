# %%
class NameOfClass():
  
  def __init__(self,param1,param2):
    self.param1 = param1
    self.param2 = param2
  
  def someMethod(self):
    # perform some action
    print(self.param1)
# Out:
# Enter a digit: -21
# Sorry but its not a digit!
# Enter a digit: 1

# %%
class MyFirstClass():
  pass

myFirstObject = MyFirstClass()  # Создание объекта класса

print(type(myFirstObject))
# Out:
# <class '__main__.MyFirstClass'>

# %%
class Car():

  wheelsNumber = 4  # Автоматически присваиваемые значения всем созданным объектам класса

  def __init__(self, name, color, year, isCrashed):
    self.name = name
    self.color = color 
    self.year = year
    self.isCrashed = isCrashed

  def drive(self):  # Создание метода класса
    print('Car is driving')

mazdaCar = Car(name='Mazda CX7', color='red', year=2017, isCrashed=True)
print(mazdaCar.name)
print(mazdaCar.color)
print(mazdaCar.year)
print(mazdaCar.isCrashed)
print(mazdaCar.wheelsNumber)  

bmwCar = Car(name='BMW', color='black', year=2015, isCrashed=False)
print(bmwCar.name, bmwCar.color, bmwCar.year, bmwCar.isCrashed, bmwCar.wheelsNumber)

numberOfWheelsOf3cars = Car.wheelsNumber * 3  # Т.к wheelsNumber аттрибут класса, то к нему можно обращаться напрямую через имя класса
print(numberOfWheelsOf3cars)

opelCar = Car('Opel Tiger', 'yellow', 1999, True)
opelCar.drive()
# Out:
# Mazda CX7
# red
# 2017
# True
# 4
# BMW black 2015 False 4
# 12
# Car drives

# %%
class BlogPost():

  text = 'Do it!'

  def __init__(self, user_name, number_of_likes):
    self.user_name = user_name
    self.number_of_likes = number_of_likes

cheatLikes = BlogPost(user_name='Hacker', number_of_likes=9999)
foodEatFood = BlogPost(user_name='Potato', number_of_likes=88)

print(cheatLikes.user_name, cheatLikes.text, cheatLikes.number_of_likes)
print(foodEatFood.user_name, foodEatFood.text, foodEatFood.number_of_likes)
# Out:
# Hacker Do it! 9999
# Potato Do it! 88

# %%
class BlogPost:
    def1 = 'x'
    def __init__(self, user_name, text, number_of_likes):
        self.user_name = user_name
        self.text = text
        self.number_of_likes = number_of_likes


post_about_politicians = BlogPost(user_name='John', text='I like politicians', number_of_likes=0)
post_about_cats = BlogPost('Jane', 'I like cats', 0)

post_about_cats.number_of_likes = 1000

print(post_about_politicians.user_name, post_about_politicians.text, post_about_politicians.number_of_likes)
print(post_about_cats.number_of_likes)
# Out:
# John I like politicians 0
# 1000 x

# %%
class Car():

  wheelsNumber = 4  # Автоматически присваиваемые значения всем созданным объектам класса

  def __init__(self, name, color, year, isCrashed):
    self.name = name
    self.color = color 
    self.year = year
    self.isCrashed = isCrashed

  def drive(self, city):  # Создание метода класса
    print(self.name + ' is driving to ' + city)

  def change_color(self, new_color):
    self.color = new_color

opelCar = Car('Opel X7', 'green', '2021', False)
opelCar.drive('Kiyv')
print(opelCar.color)
opelCar.change_color('yellow')
print(opelCar.color)
# Out:
# Opel X7 is driving to Kiyv
# green
# yellow

# %%
class Circle:
  pi = 3.14

  def __init__(self, radius=1):  # Если param=x, то объекту будет присваиваться дефолтное значение x
    self.radius = radius 
    self.get_circumference = 2 * self.pi * self.radius

  def get_area(self):  # Возвращает площадь круга
    return self.pi * (self.radius ** 2)

  # Закомментировал т.к инициализирую это и присваиваю в def __init__
  # def get_circumference(self):  # Возвращает длину окружности
  #   return 2 * self.pi * self.radius

circle_1 = Circle()
print(circle_1.get_area())
# print(circle_1.get_circumference())
print(circle_1.get_circumference)

circle_2 = Circle(3)
print(circle_2.get_area())

circle_3 = Circle(5)
circle_area = circle_3.get_area()
print(circle_area)
# Out:
# 3.14
# 6.28
# 28.26
# 78.5

# %%
class BankAccount:
  
  def __init__(self, client_id, client_first_name, client_last_name, balance=0.0):
    self.client_id = client_id
    self.client_first_name = client_first_name
    self.client_last_name = client_last_name
    self.balance = balance

  def add(self, plus):
    self.balance += plus

add1 = BankAccount('007', 'Steven', 'Hocking')
add1.add(1000)
print(add1.balance)
# Out:
# 1000.0
