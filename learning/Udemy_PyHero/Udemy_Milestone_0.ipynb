# %%
def user_choice():
  # check user input

  #VARIABLES
  #Initial
  choice = 'noDigit'
  acceptable_range = range(1,10)
  within_range = False

  # TWO CONDITIONS TO CHECK
  # Digit or in range 
  while choice.isdigit() == False or within_range == False:

    choice = input('Please enter a number (1-9): ')

    # DIGIT CHECK
    if choice.isdigit() == False:
      print('Sorry that its not a digit!')
      continue

    # RANGE CHECK
    if choice.isdigit() == True:
      if int(choice) in acceptable_range:
        within_range = True
      else:
        within_range = False
        print('Sorry you are out of acceptable range (1-9)')

  return int(choice)

user_choice()
# Out:
# Please enter a number (1-9): 2
# 2

# %%
game_list = [1, 2, 3]

def display_game(game_list):
  print('Here is the current list:')
  print(game_list)

display_game(game_list)
# Out:
# Here is the current list:
# [1, 2, 3]

# %%
def position_choice():

  choice = 'noDigit'

  while choice not in ['1', '2', '3']:

    choice = input('Pick a position (1, 2, 3): ')

    if choice not in ['1', '2', '3']:
      print('Sorry, invalid choice!')
    
  return int(choice)-1

position_choice()
# Out:
# Pick a position (1, 2, 3): 1
# 0

# %%
def replacement_value(game_list, position):

  user_placement = input('Type a string to place at position: ')

  game_list[position] = user_placement

  return game_list

replacement_value(game_list, position)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-772836115566> in <module>()
#       7   return game_list
#       8
# ----> 9 replacement_value(game_list, position)
#
# NameError: name 'position' is not defined

# %%
def gameOn_choice():

  choice = 'noDigit'

  while choice not in ['Y', 'N']:

    choice = input('Keep playing? (Y or N): ')

    if choice not in ['Y', 'N']:
      print('Sorry, I dont understand, please choose Y or N')
    
  if choice == 'Y':
    return True
  elif choice == 'N':
    return False
  else:
    return 'Sorry, invalid choice'

gameOn_choice()
# Out:
# Keep playing? (Y or N): fsdfsd
# Sorry, I dont understand, please choose Y or N
# Keep playing? (Y or N): N
# False

# %%
game_on = True
game_list = [1, 2, 3]

while game_on:

  display_game(game_list)

  position = position_choice()

  game_list = replacement_value(game_list, position)

  display_game(game_list)

  game_on = gameOn_choice()
# Out:
# Here is the current list:
# [1, 2, 3]
# Pick a position (1, 2, 3): 2
# Type a string to place at position: HELL
# Here is the current list:
# [1, 'HELL', 3]
# Keep playing? (Y or N): N
