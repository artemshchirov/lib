# %%
from django.db import models

# %%
from howto.models import *

# %%
newblog = Blog.objects.create(name='Artemeow Jupyter 1')

# %%
newblog = Blog.objects.create(name='Artemeow Jupyter 2')

# %%
all_blogs = list(Entry.objects.all)

# %%
print(all_blogs)
# Out:
# [<Blog: Artemeow Jupyter 1>, <Blog: Artemeow Jupyter 2>]

# %%
Blog.objects.order_by('?')[0:]
# Out:
# <QuerySet [<Blog: Artemeow Jupyter 2>, <Blog: Artemeow Jupyter 1>]>
